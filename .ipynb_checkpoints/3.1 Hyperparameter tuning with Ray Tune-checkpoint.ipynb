# %% [markdown]
# #TODO:
#
# - Introduction
# - Explain ray config

# %% [markdown]
# # RayTune Dashboard:
#
# When Ray is running on a (not portforwarded, dutch) server, accessing the Ray dashboard is done as follows. Given this example warning of Ray:
#
#
# `2020-11-04 17:00:40,912	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8265`
#
#
# The dashboard is accessed by opening a ssh tunnel to this port. This is done by running `ssh -NL 8265:localhost:8265 username@gpuserver.hhs.nl` in a terminal (e.g. powershell in Windows) on your computer. Once logged in you can acces the Dashboard in your webbrowser by going to `localhost:8265`.

# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler


"""
Ray config explanation.
"""


# ray config
total_num_cpus = 40 # total number of cpus to use
total_num_gpus = 4 # total numbers of gpus to use

num_gpus = 0.25 # number of gpus per trial
num_workers = 2 # number workers & number of processes for dataloaders
num_cpus_for_driver = 1 # number of cpus for driver
num_cpus_per_worker = 1 # number of cpus per worker

# Each trial uses num_cpus_per_worker * num_workers + num_cpus_for_driver CPU's

ray.shutdown()
ray.init(num_cpus=total_num_cpus, num_gpus=total_num_gpus, dashboard_port=8265) # set to your preferred (non occupied) port to have a fixed port
# Out:
# 2020-11-13 14:48:12,805	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8266
# {'node_ip_address': '145.52.252.20',
#  'raylet_ip_address': '145.52.252.20',
#  'redis_address': '145.52.252.20:6379',
#  'object_store_address': '/tmp/ray/session_2020-11-13_14-48-12_253320_5246/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-11-13_14-48-12_253320_5246/sockets/raylet',
#  'webui_url': '127.0.0.1:8266',
#  'session_dir': '/tmp/ray/session_2020-11-13_14-48-12_253320_5246',
#  'metrics_export_port': 51745}

# %%
n_cpus_per_trial = num_cpus_per_worker*num_workers + num_cpus_for_driver

print("Using %s CPUs per trial." % (n_cpus_per_trial))
print("We are able to run %s trials in parallel (disregarding gpu limitations)." % (total_num_cpus // n_cpus_per_trial))
# Out:
# Using 3 CPUs per trial.
# We are able to run 13 trials in parallel (disregarding gpu limitations).

# %% [markdown]
# # Shared definitions between trials

# %%
def load_data(data_dir="./data"):
    """
    Loads and normalises CIFAR10 data.
    """
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    
    trainset = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=transform)

    testset = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=transform)

    return trainset, testset


def test_accuracy(net, device="cpu"):
    """
    A function to compute the test accuracy
    """
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=num_workers)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
class Net(nn.Module):
    def __init__(self, l1=120, l2=84):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.fc3 = nn.Linear(l2, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train_cifar(config, checkpoint_dir=None, data_dir=None):
    net = Net(config["l1"], config["l2"])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, testset = load_data(data_dir)

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(
        trainset, [test_abs, len(trainset) - test_abs])

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=num_workers)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=num_workers)

    for epoch in range(10):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %%
# Main

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):
    data_dir = os.path.abspath("./data")
    load_data(data_dir)
    
    config = {
        "num_gpus": num_gpus,
        "num_cpus_for_driver": num_cpus_for_driver,
        "num_cpus_per_worker": num_cpus_per_worker,
        "num_workers": num_workers,
        "l1": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "l2": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "lr": tune.loguniform(1e-4, 1e-1),
        "batch_size": tune.choice([2, 4, 8, 16]),
        
    }
    
    scheduler = ASHAScheduler(
        metric="loss",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])
    
    result = tune.run(
        partial(train_cifar, data_dir=data_dir),
        resources_per_trial={"cpu": num_workers, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = Net(best_trial.config["l1"], best_trial.config["l2"])
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    
    best_trained_model.load_state_dict(model_state)

    test_acc = test_accuracy(best_trained_model, device)
    print("Best trial test set accuracy: {}".format(test_acc))


if __name__ == "__main__":
    # manually determine gpus per trial to see what's efficient
    # num samples = total number of experiments to run
    main(num_samples=10, max_num_epochs=25, gpus_per_trial=0.25)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 2020-11-13 14:48:16,342	WARNING experiment.py:256 -- No name detected on trainable. Using DEFAULT.
# 2020-11-13 14:48:16,344	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Memory usage on this node: 7.4/94.3 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2/40 CPUs, 0.25/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (99 PENDING, 1 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_e1931_00001 | PENDING  |       |           16 |   64 |  256 | 0.00120355  |
# | DEFAULT_e1931_00002 | PENDING  |       |            2 |    4 |   32 | 0.000811232 |
# | DEFAULT_e1931_00003 | PENDING  |       |           16 |  128 |    4 | 0.000676203 |
# | DEFAULT_e1931_00004 | PENDING  |       |            8 |  256 |   64 | 0.00126235  |
# | DEFAULT_e1931_00005 | PENDING  |       |            8 |   16 |    4 | 0.018445    |
# | DEFAULT_e1931_00006 | PENDING  |       |            8 |    4 |    8 | 0.022584    |
# | DEFAULT_e1931_00007 | PENDING  |       |            8 |    8 |   64 | 0.0142178   |
# | DEFAULT_e1931_00008 | PENDING  |       |            8 |  256 |  256 | 0.0399655   |
# | DEFAULT_e1931_00009 | PENDING  |       |            8 |   16 |    8 | 0.000980411 |
# | DEFAULT_e1931_00010 | PENDING  |       |           16 |    8 |   64 | 0.000851984 |
# | DEFAULT_e1931_00011 | PENDING  |       |            2 |   16 |   64 | 0.000231341 |
# | DEFAULT_e1931_00012 | PENDING  |       |            2 |   64 |   16 | 0.0332736   |
# | DEFAULT_e1931_00013 | PENDING  |       |           16 |  128 |   16 | 0.00126647  |
# | DEFAULT_e1931_00014 | PENDING  |       |            4 |  256 |   64 | 0.0364919   |
# | DEFAULT_e1931_00015 | PENDING  |       |            8 |   64 |   32 | 0.0134564   |
# | DEFAULT_e1931_00016 | PENDING  |       |            4 |  256 |    4 | 0.000144803 |
# | DEFAULT_e1931_00017 | PENDING  |       |            2 |   64 |   64 | 0.00759149  |
# | DEFAULT_e1931_00018 | PENDING  |       |            4 |  128 |  128 | 0.00141191  |
# | DEFAULT_e1931_00019 | PENDING  |       |            4 |  256 |  256 | 0.0662201   |
# | DEFAULT_e1931_00000 | RUNNING  |       |           16 |    4 |   32 | 0.00481312  |
# +---------------------+----------+-------+--------------+------+------+-------------+
# ... 80 more trials not shown (80 PENDING)
#
#
# (pid=5460) Files already downloaded and verified
# (pid=5460) Files already downloaded and verified
# (pid=5377) Files already downloaded and verified
# (pid=5451) Files already downloaded and verified
# (pid=5390) Files already downloaded and verified
# (pid=5376) Files already downloaded and verified
# (pid=5459) Files already downloaded and verified
# (pid=5444) Files already downloaded and verified
# (pid=5399) Files already downloaded and verified
# (pid=5400) Files already downloaded and verified
# (pid=5397) Files already downloaded and verified
# (pid=5466) Files already downloaded and verified
# (pid=5393) Files already downloaded and verified
# (pid=5379) Files already downloaded and verified
# (pid=5386) Files already downloaded and verified
# (pid=5373) Files already downloaded and verified
# (pid=5380) Files already downloaded and verified
# (pid=5377) Files already downloaded and verified
# (pid=5451) Files already downloaded and verified
# (pid=5399) Files already downloaded and verified
# (pid=5390) Files already downloaded and verified
# (pid=5376) Files already downloaded and verified
# (pid=5459) Files already downloaded and verified
# (pid=5444) Files already downloaded and verified
# (pid=5397) Files already downloaded and verified
# (pid=5400) Files already downloaded and verified
# (pid=5386) Files already downloaded and verified
# (pid=5466) Files already downloaded and verified
# (pid=5393) Files already downloaded and verified
# (pid=5380) Files already downloaded and verified
# (pid=5379) Files already downloaded and verified
# (pid=5373) Files already downloaded and verified
# (pid=5460) [1,  2000] loss: 2.320
# (pid=5377) [1,  2000] loss: 2.277
# (pid=5399) [1,  2000] loss: 2.193
# (pid=5376) [1,  2000] loss: 1.891
# (pid=5390) [1,  2000] loss: 2.193
# (pid=5397) [1,  2000] loss: 2.138
# (pid=5444) [1,  2000] loss: 2.250
# (pid=5451) [1,  2000] loss: 2.294
# (pid=5400) [1,  2000] loss: 2.149
# (pid=5380) [1,  2000] loss: 1.975
# (pid=5373) [1,  2000] loss: 2.032
# (pid=5393) [1,  2000] loss: 2.139
# (pid=5466) [1,  2000] loss: 2.162
# (pid=5459) [1,  2000] loss: 2.308
# (pid=5386) [1,  2000] loss: 2.340
# (pid=5379) [1,  2000] loss: 2.302
# Result for DEFAULT_e1931_00000:
#   accuracy: 0.3818
#   date: 2020-11-13_14-48-52
#   done: false
#   experiment_id: 90eeb897d8a14f088e22e469ccd4fe05
#   experiment_tag: 0_batch_size=16,l1=4,l2=32,lr=0.0048131
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.6325293214797973
#   node_ip: 145.52.252.20
#   pid: 5376
#   should_checkpoint: true
#   time_since_restore: 34.326000452041626
#   time_this_iter_s: 34.326000452041626
#   time_total_s: 34.326000452041626
#   timestamp: 1605275332
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00000
#
# == Status ==
# Memory usage on this node: 50.0/94.3 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.6325293214797973
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (84 PENDING, 16 RUNNING)
# +---------------------+----------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00016 | PENDING  |                    |            4 |  256 |    4 | 0.000144803 |         |            |                      |
# | DEFAULT_e1931_00017 | PENDING  |                    |            2 |   64 |   64 | 0.00759149  |         |            |                      |
# | DEFAULT_e1931_00018 | PENDING  |                    |            4 |  128 |  128 | 0.00141191  |         |            |                      |
# | DEFAULT_e1931_00019 | PENDING  |                    |            4 |  256 |  256 | 0.0662201   |         |            |                      |
# | DEFAULT_e1931_00020 | PENDING  |                    |            2 |    4 |  256 | 0.0286478   |         |            |                      |
# | DEFAULT_e1931_00021 | PENDING  |                    |           16 |  128 |  128 | 0.0110741   |         |            |                      |
# | DEFAULT_e1931_00022 | PENDING  |                    |            2 |  256 |   32 | 0.000735972 |         |            |                      |
# | DEFAULT_e1931_00023 | PENDING  |                    |           16 |  256 |  128 | 0.00023935  |         |            |                      |
# | DEFAULT_e1931_00024 | PENDING  |                    |            8 |  256 |   64 | 0.0352421   |         |            |                      |
# | DEFAULT_e1931_00025 | PENDING  |                    |            8 |   16 |   64 | 0.00427362  |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING  | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.63253 |     0.3818 |                    1 |
# | DEFAULT_e1931_00001 | RUNNING  |                    |           16 |   64 |  256 | 0.00120355  |         |            |                      |
# | DEFAULT_e1931_00002 | RUNNING  |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00003 | RUNNING  |                    |           16 |  128 |    4 | 0.000676203 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING  |                    |            8 |  256 |   64 | 0.00126235  |         |            |                      |
# | DEFAULT_e1931_00005 | RUNNING  |                    |            8 |   16 |    4 | 0.018445    |         |            |                      |
# | DEFAULT_e1931_00006 | RUNNING  |                    |            8 |    4 |    8 | 0.022584    |         |            |                      |
# | DEFAULT_e1931_00007 | RUNNING  |                    |            8 |    8 |   64 | 0.0142178   |         |            |                      |
# | DEFAULT_e1931_00008 | RUNNING  |                    |            8 |  256 |  256 | 0.0399655   |         |            |                      |
# | DEFAULT_e1931_00009 | RUNNING  |                    |            8 |   16 |    8 | 0.000980411 |         |            |                      |
# +---------------------+----------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (74 PENDING, 6 RUNNING)
#
#
# Result for DEFAULT_e1931_00001:
#   accuracy: 0.3546
#   date: 2020-11-13_14-48-52
#   done: true
#   experiment_id: c8ba92929142413e8bcaf0411be610ed
#   experiment_tag: 1_batch_size=16,l1=64,l2=256,lr=0.0012035
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.7389490594863892
#   node_ip: 145.52.252.20
#   pid: 5400
#   should_checkpoint: true
#   time_since_restore: 34.42833209037781
#   time_this_iter_s: 34.42833209037781
#   time_total_s: 34.42833209037781
#   timestamp: 1605275332
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00001
# Result for DEFAULT_e1931_00010:
#   accuracy: 0.2928
#   date: 2020-11-13_14-48-52
#   done: true
#   experiment_id: 4d112dadcaae4b879669fa4e2ffb603e
#   experiment_tag: 10_batch_size=16,l1=8,l2=64,lr=0.00085198
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.8478457763671876
#   node_ip: 145.52.252.20
#   pid: 5390
#   should_checkpoint: true
#   time_since_restore: 34.40496563911438
#   time_this_iter_s: 34.40496563911438
#   time_total_s: 34.40496563911438
#   timestamp: 1605275332
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00010
#
# Result for DEFAULT_e1931_00013:
#   accuracy: 0.3499
#   date: 2020-11-13_14-48-52
#   done: true
#   experiment_id: 9d559e7839174804afaeddf7a021b981
#   experiment_tag: 13_batch_size=16,l1=128,l2=16,lr=0.0012665
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.7425559041976928
#   node_ip: 145.52.252.20
#   pid: 5393
#   should_checkpoint: true
#   time_since_restore: 34.64450263977051
#   time_this_iter_s: 34.64450263977051
#   time_total_s: 34.64450263977051
#   timestamp: 1605275332
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00013
#
# Result for DEFAULT_e1931_00003:
#   accuracy: 0.1496
#   date: 2020-11-13_14-48-52
#   done: true
#   experiment_id: 324a9427e34344eeaa130c9c36e758d1
#   experiment_tag: 3_batch_size=16,l1=128,l2=4,lr=0.0006762
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.24585920753479
#   node_ip: 145.52.252.20
#   pid: 5459
#   should_checkpoint: true
#   time_since_restore: 35.21849822998047
#   time_this_iter_s: 35.21849822998047
#   time_total_s: 35.21849822998047
#   timestamp: 1605275332
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00003
#
# (pid=5399) [1,  4000] loss: 1.095
# (pid=5460) [1,  4000] loss: 1.162
# (pid=5397) [1,  4000] loss: 0.854
# (pid=5380) [1,  4000] loss: 0.916
# (pid=5373) [1,  4000] loss: 0.964
# (pid=5466) [1,  4000] loss: 1.072
# (pid=5377) [1,  4000] loss: 1.003
# (pid=5386) [1,  4000] loss: 1.171
# (pid=5379) [1,  4000] loss: 1.142
# (pid=5444) [1,  4000] loss: 1.151
# (pid=5451) [1,  4000] loss: 1.082
# (pid=5388) Files already downloaded and verified
# (pid=5464) Files already downloaded and verified
# (pid=5382) Files already downloaded and verified
# (pid=5372) Files already downloaded and verified
# (pid=5388) Files already downloaded and verified
# (pid=5382) Files already downloaded and verified
# (pid=5464) Files already downloaded and verified
# (pid=5372) Files already downloaded and verified
# (pid=5376) [2,  2000] loss: 1.571
# Result for DEFAULT_e1931_00008:
#   accuracy: 0.1636
#   date: 2020-11-13_14-49-07
#   done: true
#   experiment_id: 88509853ac0c4166bb92f7a3238fcf2e
#   experiment_tag: 8_batch_size=8,l1=256,l2=256,lr=0.039965
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.184899582862854
#   node_ip: 145.52.252.20
#   pid: 5399
#   should_checkpoint: true
#   time_since_restore: 50.2731556892395
#   time_this_iter_s: 50.2731556892395
#   time_total_s: 50.2731556892395
#   timestamp: 1605275347
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00008
#
# == Status ==
# Memory usage on this node: 49.9/94.3 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.7952008402824402
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (80 PENDING, 16 RUNNING, 4 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00020 | PENDING    |                    |            2 |    4 |  256 | 0.0286478   |         |            |                      |
# | DEFAULT_e1931_00021 | PENDING    |                    |           16 |  128 |  128 | 0.0110741   |         |            |                      |
# | DEFAULT_e1931_00022 | PENDING    |                    |            2 |  256 |   32 | 0.000735972 |         |            |                      |
# | DEFAULT_e1931_00023 | PENDING    |                    |           16 |  256 |  128 | 0.00023935  |         |            |                      |
# | DEFAULT_e1931_00024 | PENDING    |                    |            8 |  256 |   64 | 0.0352421   |         |            |                      |
# | DEFAULT_e1931_00025 | PENDING    |                    |            8 |   16 |   64 | 0.00427362  |         |            |                      |
# | DEFAULT_e1931_00026 | PENDING    |                    |           16 |    8 |   16 | 0.00409285  |         |            |                      |
# | DEFAULT_e1931_00027 | PENDING    |                    |            4 |  256 |    4 | 0.00763769  |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.63253 |     0.3818 |                    1 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    |                    |            8 |  256 |   64 | 0.00126235  |         |            |                      |
# | DEFAULT_e1931_00005 | RUNNING    |                    |            8 |   16 |    4 | 0.018445    |         |            |                      |
# | DEFAULT_e1931_00006 | RUNNING    |                    |            8 |    4 |    8 | 0.022584    |         |            |                      |
# | DEFAULT_e1931_00007 | RUNNING    |                    |            8 |    8 |   64 | 0.0142178   |         |            |                      |
# | DEFAULT_e1931_00008 | RUNNING    | 145.52.252.20:5399 |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00009 | RUNNING    |                    |            8 |   16 |    8 | 0.000980411 |         |            |                      |
# | DEFAULT_e1931_00001 | TERMINATED |                    |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00003 | TERMINATED |                    |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00010 | TERMINATED |                    |           16 |    8 |   64 | 0.000851984 | 1.84785 |     0.2928 |                    1 |
# | DEFAULT_e1931_00013 | TERMINATED |                    |           16 |  128 |   16 | 0.00126647  | 1.74256 |     0.3499 |                    1 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (72 PENDING, 8 RUNNING)
#
#
# Result for DEFAULT_e1931_00004:
#   accuracy: 0.4457
#   date: 2020-11-13_14-49-07
#   done: false
#   experiment_id: d40c806e9bd146c7ab6985bbb3b9e8f2
#   experiment_tag: 4_batch_size=8,l1=256,l2=64,lr=0.0012624
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.5173140350341796
#   node_ip: 145.52.252.20
#   pid: 5397
#   should_checkpoint: true
#   time_since_restore: 50.21714901924133
#   time_this_iter_s: 50.21714901924133
#   time_total_s: 50.21714901924133
#   timestamp: 1605275347
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00004
#
# Result for DEFAULT_e1931_00015:
#   accuracy: 0.3551
#   date: 2020-11-13_14-49-08
#   done: true
#   experiment_id: 900c943a9d1d43edad5fb16b81c06a93
#   experiment_tag: 15_batch_size=8,l1=64,l2=32,lr=0.013456
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.757356064748764
#   node_ip: 145.52.252.20
#   pid: 5380
#   should_checkpoint: true
#   time_since_restore: 50.026206970214844
#   time_this_iter_s: 50.026206970214844
#   time_total_s: 50.026206970214844
#   timestamp: 1605275348
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00015
# Result for DEFAULT_e1931_00007:
#   accuracy: 0.2667
#   date: 2020-11-13_14-49-08
#   done: true
#   experiment_id: 338b12b3d7914e73b44793d77684f2e7
#   experiment_tag: 7_batch_size=8,l1=8,l2=64,lr=0.014218
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.9422798272132873
#   node_ip: 145.52.252.20
#   pid: 5373
#   should_checkpoint: true
#   time_since_restore: 50.50981545448303
#   time_this_iter_s: 50.50981545448303
#   time_total_s: 50.50981545448303
#   timestamp: 1605275348
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00007
#
# Result for DEFAULT_e1931_00005:
#   accuracy: 0.1311
#   date: 2020-11-13_14-49-08
#   done: true
#   experiment_id: 24857da790144ee0b4c4876b8ce0bf7c
#   experiment_tag: 5_batch_size=8,l1=16,l2=4,lr=0.018445
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.2229816040992736
#   node_ip: 145.52.252.20
#   pid: 5466
#   should_checkpoint: true
#   time_since_restore: 50.71414804458618
#   time_this_iter_s: 50.71414804458618
#   time_total_s: 50.71414804458618
#   timestamp: 1605275348
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00005
#
# Result for DEFAULT_e1931_00009:
#   accuracy: 0.2933
#   date: 2020-11-13_14-49-09
#   done: false
#   experiment_id: 3a9ce3d5022e45afac9a3460d6830e6d
#   experiment_tag: 9_batch_size=8,l1=16,l2=8,lr=0.00098041
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.7713964731216432
#   node_ip: 145.52.252.20
#   pid: 5377
#   should_checkpoint: true
#   time_since_restore: 52.02078986167908
#   time_this_iter_s: 52.02078986167908
#   time_total_s: 52.02078986167908
#   timestamp: 1605275349
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00009
#
# (pid=5386) [1,  6000] loss: 0.779
# Result for DEFAULT_e1931_00006:
#   accuracy: 0.1023
#   date: 2020-11-13_14-49-10
#   done: true
#   experiment_id: 94ab3ea95afe40e089d3eb52a10e1ee3
#   experiment_tag: 6_batch_size=8,l1=4,l2=8,lr=0.022584
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.3091005405426026
#   node_ip: 145.52.252.20
#   pid: 5444
#   should_checkpoint: true
#   time_since_restore: 53.082218647003174
#   time_this_iter_s: 53.082218647003174
#   time_total_s: 53.082218647003174
#   timestamp: 1605275350
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00006
#
# (pid=5379) [1,  6000] loss: 0.713
# (pid=5460) [1,  6000] loss: 0.775
# Result for DEFAULT_e1931_00000:
#   accuracy: 0.44
#   date: 2020-11-13_14-49-12
#   done: false
#   experiment_id: 90eeb897d8a14f088e22e469ccd4fe05
#   experiment_tag: 0_batch_size=16,l1=4,l2=32,lr=0.0048131
#   hostname: gpuserver
#   iterations_since_restore: 2
#   loss: 1.5221145632743835
#   node_ip: 145.52.252.20
#   pid: 5376
#   should_checkpoint: true
#   time_since_restore: 54.24675536155701
#   time_this_iter_s: 19.92075490951538
#   time_total_s: 54.24675536155701
#   timestamp: 1605275352
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e1931_00000
#
# (pid=5451) [1,  6000] loss: 0.643
# (pid=5388) [1,  2000] loss: 2.330
# (pid=5405) Files already downloaded and verified
# (pid=5384) Files already downloaded and verified
# (pid=5382) [1,  2000] loss: 2.206
# (pid=5461) Files already downloaded and verified
# (pid=5372) [1,  2000] loss: 2.340
# (pid=5383) Files already downloaded and verified
# (pid=5464) [1,  2000] loss: 2.193
# (pid=5405) Files already downloaded and verified
# (pid=5384) Files already downloaded and verified
# (pid=5383) Files already downloaded and verified
# (pid=5461) Files already downloaded and verified
# (pid=5401) Files already downloaded and verified
# (pid=5401) Files already downloaded and verified
# (pid=5397) [2,  2000] loss: 1.471
# (pid=5377) [2,  2000] loss: 1.750
# (pid=5386) [1,  8000] loss: 0.584
# (pid=5460) [1,  8000] loss: 0.581
# (pid=5379) [1,  8000] loss: 0.503
# (pid=5376) [3,  2000] loss: 1.465
# (pid=5451) [1,  8000] loss: 0.458
# (pid=5388) [1,  4000] loss: 1.160
# (pid=5372) [1,  4000] loss: 1.171
# (pid=5382) [1,  4000] loss: 0.908
# (pid=5464) [1,  4000] loss: 1.067
# (pid=5405) [1,  2000] loss: 1.748
# Result for DEFAULT_e1931_00000:
#   accuracy: 0.4586
#   date: 2020-11-13_14-49-30
#   done: false
#   experiment_id: 90eeb897d8a14f088e22e469ccd4fe05
#   experiment_tag: 0_batch_size=16,l1=4,l2=32,lr=0.0048131
#   hostname: gpuserver
#   iterations_since_restore: 3
#   loss: 1.4642308653831482
#   node_ip: 145.52.252.20
#   pid: 5376
#   should_checkpoint: true
#   time_since_restore: 73.06858229637146
#   time_this_iter_s: 18.821826934814453
#   time_total_s: 73.06858229637146
#   timestamp: 1605275370
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: e1931_00000
#
# == Status ==
# Memory usage on this node: 50.2/94.3 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.5221145632743835 | Iter 1.000: -1.8096211247444154
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (75 PENDING, 16 RUNNING, 9 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00025 | PENDING    |                    |            8 |   16 |   64 | 0.00427362  |         |            |                      |
# | DEFAULT_e1931_00026 | PENDING    |                    |           16 |    8 |   16 | 0.00409285  |         |            |                      |
# | DEFAULT_e1931_00027 | PENDING    |                    |            4 |  256 |    4 | 0.00763769  |         |            |                      |
# | DEFAULT_e1931_00028 | PENDING    |                    |            8 |    4 |   64 | 0.00285792  |         |            |                      |
# | DEFAULT_e1931_00029 | PENDING    |                    |            8 |    8 |  256 | 0.0161909   |         |            |                      |
# | DEFAULT_e1931_00030 | PENDING    |                    |            8 |    4 |  256 | 0.00016834  |         |            |                      |
# | DEFAULT_e1931_00031 | PENDING    |                    |            2 |   32 |  128 | 0.000164034 |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.46423 |     0.4586 |                    3 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    | 145.52.252.20:5397 |            8 |  256 |   64 | 0.00126235  | 1.51731 |     0.4457 |                    1 |
# | DEFAULT_e1931_00009 | RUNNING    | 145.52.252.20:5377 |            8 |   16 |    8 | 0.000980411 | 1.7714  |     0.2933 |                    1 |
# | DEFAULT_e1931_00011 | RUNNING    |                    |            2 |   16 |   64 | 0.000231341 |         |            |                      |
# | DEFAULT_e1931_00012 | RUNNING    |                    |            2 |   64 |   16 | 0.0332736   |         |            |                      |
# | DEFAULT_e1931_00014 | RUNNING    |                    |            4 |  256 |   64 | 0.0364919   |         |            |                      |
# | DEFAULT_e1931_00001 | TERMINATED |                    |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00003 | TERMINATED |                    |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00005 | TERMINATED |                    |            8 |   16 |    4 | 0.018445    | 2.22298 |     0.1311 |                    1 |
# | DEFAULT_e1931_00006 | TERMINATED |                    |            8 |    4 |    8 | 0.022584    | 2.3091  |     0.1023 |                    1 |
# | DEFAULT_e1931_00007 | TERMINATED |                    |            8 |    8 |   64 | 0.0142178   | 1.94228 |     0.2667 |                    1 |
# | DEFAULT_e1931_00008 | TERMINATED |                    |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00010 | TERMINATED |                    |           16 |    8 |   64 | 0.000851984 | 1.84785 |     0.2928 |                    1 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (68 PENDING, 9 RUNNING, 2 TERMINATED)
# (pid=5384) [1,  2000] loss: 2.343
# (pid=5383) [1,  2000] loss: 2.274
# (pid=5461) [1,  2000] loss: 2.301
# (pid=5397) [2,  4000] loss: 0.702
# (pid=5401) [1,  2000] loss: 2.197
# (pid=5377) [2,  4000] loss: 0.841
# (pid=5386) [1, 10000] loss: 0.468
# (pid=5379) [1, 10000] loss: 0.383
# (pid=5460) [1, 10000] loss: 0.465
# Result for DEFAULT_e1931_00021:
#   accuracy: 0.4655
#   date: 2020-11-13_14-49-35
#   done: false
#   experiment_id: 871d1ed32e754ae28829db7dd67f82e0
#   experiment_tag: 21_batch_size=16,l1=128,l2=128,lr=0.011074
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 1.4852743953704834
#   node_ip: 145.52.252.20
#   pid: 5405
#   should_checkpoint: true
#   time_since_restore: 26.63757610321045
#   time_this_iter_s: 26.63757610321045
#   time_total_s: 26.63757610321045
#   timestamp: 1605275375
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00021
#
# == Status ==
# Memory usage on this node: 50.0/94.3 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.5221145632743835 | Iter 1.000: -1.7713964731216432
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (75 PENDING, 16 RUNNING, 9 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00025 | PENDING    |                    |            8 |   16 |   64 | 0.00427362  |         |            |                      |
# | DEFAULT_e1931_00026 | PENDING    |                    |           16 |    8 |   16 | 0.00409285  |         |            |                      |
# | DEFAULT_e1931_00027 | PENDING    |                    |            4 |  256 |    4 | 0.00763769  |         |            |                      |
# | DEFAULT_e1931_00028 | PENDING    |                    |            8 |    4 |   64 | 0.00285792  |         |            |                      |
# | DEFAULT_e1931_00029 | PENDING    |                    |            8 |    8 |  256 | 0.0161909   |         |            |                      |
# | DEFAULT_e1931_00030 | PENDING    |                    |            8 |    4 |  256 | 0.00016834  |         |            |                      |
# | DEFAULT_e1931_00031 | PENDING    |                    |            2 |   32 |  128 | 0.000164034 |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.46423 |     0.4586 |                    3 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    | 145.52.252.20:5397 |            8 |  256 |   64 | 0.00126235  | 1.51731 |     0.4457 |                    1 |
# | DEFAULT_e1931_00009 | RUNNING    | 145.52.252.20:5377 |            8 |   16 |    8 | 0.000980411 | 1.7714  |     0.2933 |                    1 |
# | DEFAULT_e1931_00011 | RUNNING    |                    |            2 |   16 |   64 | 0.000231341 |         |            |                      |
# | DEFAULT_e1931_00012 | RUNNING    |                    |            2 |   64 |   16 | 0.0332736   |         |            |                      |
# | DEFAULT_e1931_00014 | RUNNING    |                    |            4 |  256 |   64 | 0.0364919   |         |            |                      |
# | DEFAULT_e1931_00001 | TERMINATED |                    |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00003 | TERMINATED |                    |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00005 | TERMINATED |                    |            8 |   16 |    4 | 0.018445    | 2.22298 |     0.1311 |                    1 |
# | DEFAULT_e1931_00006 | TERMINATED |                    |            8 |    4 |    8 | 0.022584    | 2.3091  |     0.1023 |                    1 |
# | DEFAULT_e1931_00007 | TERMINATED |                    |            8 |    8 |   64 | 0.0142178   | 1.94228 |     0.2667 |                    1 |
# | DEFAULT_e1931_00008 | TERMINATED |                    |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00010 | TERMINATED |                    |           16 |    8 |   64 | 0.000851984 | 1.84785 |     0.2928 |                    1 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (68 PENDING, 9 RUNNING, 2 TERMINATED)
#
#
# Result for DEFAULT_e1931_00023:
#   accuracy: 0.1738
#   date: 2020-11-13_14-49-36
#   done: true
#   experiment_id: a32d15933a2244fca879df32c993f036
#   experiment_tag: 23_batch_size=16,l1=256,l2=128,lr=0.00023935
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.2922705741882323
#   node_ip: 145.52.252.20
#   pid: 5461
#   should_checkpoint: true
#   time_since_restore: 27.40821647644043
#   time_this_iter_s: 27.40821647644043
#   time_total_s: 27.40821647644043
#   timestamp: 1605275376
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00023
#
# (pid=5451) [1, 10000] loss: 0.353
# (pid=5388) [1,  6000] loss: 0.771
# (pid=5372) [1,  6000] loss: 0.781
# (pid=5382) [1,  6000] loss: 0.549
# (pid=5464) [1,  6000] loss: 0.704
# Result for DEFAULT_e1931_00004:
#   accuracy: 0.5268
#   date: 2020-11-13_14-49-42
#   done: false
#   experiment_id: d40c806e9bd146c7ab6985bbb3b9e8f2
#   experiment_tag: 4_batch_size=8,l1=256,l2=64,lr=0.0012624
#   hostname: gpuserver
#   iterations_since_restore: 2
#   loss: 1.317726478099823
#   node_ip: 145.52.252.20
#   pid: 5397
#   should_checkpoint: true
#   time_since_restore: 84.71587443351746
#   time_this_iter_s: 34.49872541427612
#   time_total_s: 84.71587443351746
#   timestamp: 1605275382
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e1931_00004
#
# == Status ==
# Memory usage on this node: 49.1/94.3 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.4199205206871033 | Iter 1.000: -1.8096211247444154
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (74 PENDING, 16 RUNNING, 10 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00026 | PENDING    |                    |           16 |    8 |   16 | 0.00409285  |         |            |                      |
# | DEFAULT_e1931_00027 | PENDING    |                    |            4 |  256 |    4 | 0.00763769  |         |            |                      |
# | DEFAULT_e1931_00028 | PENDING    |                    |            8 |    4 |   64 | 0.00285792  |         |            |                      |
# | DEFAULT_e1931_00029 | PENDING    |                    |            8 |    8 |  256 | 0.0161909   |         |            |                      |
# | DEFAULT_e1931_00030 | PENDING    |                    |            8 |    4 |  256 | 0.00016834  |         |            |                      |
# | DEFAULT_e1931_00031 | PENDING    |                    |            2 |   32 |  128 | 0.000164034 |         |            |                      |
# | DEFAULT_e1931_00032 | PENDING    |                    |            4 |  128 |   16 | 0.0615515   |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.46423 |     0.4586 |                    3 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    | 145.52.252.20:5397 |            8 |  256 |   64 | 0.00126235  | 1.31773 |     0.5268 |                    2 |
# | DEFAULT_e1931_00009 | RUNNING    | 145.52.252.20:5377 |            8 |   16 |    8 | 0.000980411 | 1.7714  |     0.2933 |                    1 |
# | DEFAULT_e1931_00011 | RUNNING    |                    |            2 |   16 |   64 | 0.000231341 |         |            |                      |
# | DEFAULT_e1931_00012 | RUNNING    |                    |            2 |   64 |   16 | 0.0332736   |         |            |                      |
# | DEFAULT_e1931_00014 | RUNNING    |                    |            4 |  256 |   64 | 0.0364919   |         |            |                      |
# | DEFAULT_e1931_00001 | TERMINATED |                    |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00003 | TERMINATED |                    |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00005 | TERMINATED |                    |            8 |   16 |    4 | 0.018445    | 2.22298 |     0.1311 |                    1 |
# | DEFAULT_e1931_00006 | TERMINATED |                    |            8 |    4 |    8 | 0.022584    | 2.3091  |     0.1023 |                    1 |
# | DEFAULT_e1931_00007 | TERMINATED |                    |            8 |    8 |   64 | 0.0142178   | 1.94228 |     0.2667 |                    1 |
# | DEFAULT_e1931_00008 | TERMINATED |                    |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00010 | TERMINATED |                    |           16 |    8 |   64 | 0.000851984 | 1.84785 |     0.2928 |                    1 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (67 PENDING, 9 RUNNING, 3 TERMINATED)
# (pid=5383) [1,  4000] loss: 1.014
# (pid=5384) [1,  4000] loss: 1.167
# (pid=5376) [4,  2000] loss: 1.415
# (pid=5395) Files already downloaded and verified
# Result for DEFAULT_e1931_00009:
#   accuracy: 0.3787
#   date: 2020-11-13_14-49-44
#   done: true
#   experiment_id: 3a9ce3d5022e45afac9a3460d6830e6d
#   experiment_tag: 9_batch_size=8,l1=16,l2=8,lr=0.00098041
#   hostname: gpuserver
#   iterations_since_restore: 2
#   loss: 1.6308152586460114
#   node_ip: 145.52.252.20
#   pid: 5377
#   should_checkpoint: true
#   time_since_restore: 86.75754928588867
#   time_this_iter_s: 34.736759424209595
#   time_total_s: 86.75754928588867
#   timestamp: 1605275384
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e1931_00009
#
# (pid=5395) Files already downloaded and verified
# Result for DEFAULT_e1931_00014:
#   accuracy: 0.0988
#   date: 2020-11-13_14-49-45
#   done: true
#   experiment_id: 396d48e802214c9ea32800128ef0955d
#   experiment_tag: 14_batch_size=4,l1=256,l2=64,lr=0.036492
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.3182375694274904
#   node_ip: 145.52.252.20
#   pid: 5460
#   should_checkpoint: true
#   time_since_restore: 87.93301153182983
#   time_this_iter_s: 87.93301153182983
#   time_total_s: 87.93301153182983
#   timestamp: 1605275385
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00014
#
# (pid=5401) [1,  4000] loss: 1.072
# (pid=5386) [1, 12000] loss: 0.390
# (pid=5379) [1, 12000] loss: 0.311
# (pid=5405) [2,  2000] loss: 1.437
# Result for DEFAULT_e1931_00000:
#   accuracy: 0.4902
#   date: 2020-11-13_14-49-49
#   done: false
#   experiment_id: 90eeb897d8a14f088e22e469ccd4fe05
#   experiment_tag: 0_batch_size=16,l1=4,l2=32,lr=0.0048131
#   hostname: gpuserver
#   iterations_since_restore: 4
#   loss: 1.3866280179023742
#   node_ip: 145.52.252.20
#   pid: 5376
#   should_checkpoint: true
#   time_since_restore: 91.63091254234314
#   time_this_iter_s: 18.56233024597168
#   time_total_s: 91.63091254234314
#   timestamp: 1605275389
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: e1931_00000
#
# == Status ==
# Memory usage on this node: 47.1/94.3 GiB
# Using AsyncHyperBand: num_stopped=12
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -1.3866280179023742 | Iter 2.000: -1.5221145632743835 | Iter 1.000: -1.8478457763671876
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (72 PENDING, 16 RUNNING, 12 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00028 | PENDING    |                    |            8 |    4 |   64 | 0.00285792  |         |            |                      |
# | DEFAULT_e1931_00029 | PENDING    |                    |            8 |    8 |  256 | 0.0161909   |         |            |                      |
# | DEFAULT_e1931_00030 | PENDING    |                    |            8 |    4 |  256 | 0.00016834  |         |            |                      |
# | DEFAULT_e1931_00031 | PENDING    |                    |            2 |   32 |  128 | 0.000164034 |         |            |                      |
# | DEFAULT_e1931_00032 | PENDING    |                    |            4 |  128 |   16 | 0.0615515   |         |            |                      |
# | DEFAULT_e1931_00033 | PENDING    |                    |            4 |    4 |    4 | 0.0415738   |         |            |                      |
# | DEFAULT_e1931_00034 | PENDING    |                    |            8 |    8 |  128 | 0.0121234   |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.38663 |     0.4902 |                    4 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    | 145.52.252.20:5397 |            8 |  256 |   64 | 0.00126235  | 1.31773 |     0.5268 |                    2 |
# | DEFAULT_e1931_00011 | RUNNING    |                    |            2 |   16 |   64 | 0.000231341 |         |            |                      |
# | DEFAULT_e1931_00012 | RUNNING    |                    |            2 |   64 |   16 | 0.0332736   |         |            |                      |
# | DEFAULT_e1931_00016 | RUNNING    |                    |            4 |  256 |    4 | 0.000144803 |         |            |                      |
# | DEFAULT_e1931_00017 | RUNNING    |                    |            2 |   64 |   64 | 0.00759149  |         |            |                      |
# | DEFAULT_e1931_00001 | TERMINATED |                    |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00003 | TERMINATED |                    |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00005 | TERMINATED |                    |            8 |   16 |    4 | 0.018445    | 2.22298 |     0.1311 |                    1 |
# | DEFAULT_e1931_00006 | TERMINATED |                    |            8 |    4 |    8 | 0.022584    | 2.3091  |     0.1023 |                    1 |
# | DEFAULT_e1931_00007 | TERMINATED |                    |            8 |    8 |   64 | 0.0142178   | 1.94228 |     0.2667 |                    1 |
# | DEFAULT_e1931_00008 | TERMINATED |                    |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00009 | TERMINATED |                    |            8 |   16 |    8 | 0.000980411 | 1.63082 |     0.3787 |                    2 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (65 PENDING, 9 RUNNING, 5 TERMINATED)
#
#
# (pid=5451) [1, 12000] loss: 0.284
# (pid=5446) Files already downloaded and verified
# (pid=5385) Files already downloaded and verified
# (pid=5388) [1,  8000] loss: 0.577
# (pid=5446) Files already downloaded and verified
# (pid=5372) [1,  8000] loss: 0.586
# Result for DEFAULT_e1931_00021:
#   accuracy: 0.5114
#   date: 2020-11-13_14-49-53
#   done: false
#   experiment_id: 871d1ed32e754ae28829db7dd67f82e0
#   experiment_tag: 21_batch_size=16,l1=128,l2=128,lr=0.011074
#   hostname: gpuserver
#   iterations_since_restore: 2
#   loss: 1.3609810041427612
#   node_ip: 145.52.252.20
#   pid: 5405
#   should_checkpoint: true
#   time_since_restore: 44.2944278717041
#   time_this_iter_s: 17.656851768493652
#   time_total_s: 44.2944278717041
#   timestamp: 1605275393
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e1931_00021
#
# (pid=5382) [1,  8000] loss: 0.392
# (pid=5385) Files already downloaded and verified
# (pid=5464) [1,  8000] loss: 0.536
# (pid=5397) [3,  2000] loss: 1.289
# (pid=5383) [1,  6000] loss: 0.611
# (pid=5384) [1,  6000] loss: 0.779
# Result for DEFAULT_e1931_00024:
#   accuracy: 0.2021
#   date: 2020-11-13_14-49-57
#   done: true
#   experiment_id: df719ff1b3e548d58f3ec0307c6acd01
#   experiment_tag: 24_batch_size=8,l1=256,l2=64,lr=0.035242
#   hostname: gpuserver
#   iterations_since_restore: 1
#   loss: 2.1059485851287842
#   node_ip: 145.52.252.20
#   pid: 5401
#   should_checkpoint: true
#   time_since_restore: 45.19179821014404
#   time_this_iter_s: 45.19179821014404
#   time_total_s: 45.19179821014404
#   timestamp: 1605275397
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e1931_00024
#
# == Status ==
# Memory usage on this node: 49.8/94.3 GiB
# Using AsyncHyperBand: num_stopped=13
# Bracket: Iter 16.000: None | Iter 8.000: None | Iter 4.000: -1.3866280179023742 | Iter 2.000: -1.4415477837085724 | Iter 1.000: -1.8950628017902376
# Resources requested: 32/40 CPUs, 4.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (72 PENDING, 16 RUNNING, 12 TERMINATED)
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc                |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00028 | PENDING    |                    |            8 |    4 |   64 | 0.00285792  |         |            |                      |
# | DEFAULT_e1931_00029 | PENDING    |                    |            8 |    8 |  256 | 0.0161909   |         |            |                      |
# | DEFAULT_e1931_00030 | PENDING    |                    |            8 |    4 |  256 | 0.00016834  |         |            |                      |
# | DEFAULT_e1931_00031 | PENDING    |                    |            2 |   32 |  128 | 0.000164034 |         |            |                      |
# | DEFAULT_e1931_00032 | PENDING    |                    |            4 |  128 |   16 | 0.0615515   |         |            |                      |
# | DEFAULT_e1931_00033 | PENDING    |                    |            4 |    4 |    4 | 0.0415738   |         |            |                      |
# | DEFAULT_e1931_00034 | PENDING    |                    |            8 |    8 |  128 | 0.0121234   |         |            |                      |
# | DEFAULT_e1931_00000 | RUNNING    | 145.52.252.20:5376 |           16 |    4 |   32 | 0.00481312  | 1.38663 |     0.4902 |                    4 |
# | DEFAULT_e1931_00002 | RUNNING    |                    |            2 |    4 |   32 | 0.000811232 |         |            |                      |
# | DEFAULT_e1931_00004 | RUNNING    | 145.52.252.20:5397 |            8 |  256 |   64 | 0.00126235  | 1.31773 |     0.5268 |                    2 |
# | DEFAULT_e1931_00011 | RUNNING    |                    |            2 |   16 |   64 | 0.000231341 |         |            |                      |
# | DEFAULT_e1931_00012 | RUNNING    |                    |            2 |   64 |   16 | 0.0332736   |         |            |                      |
# ...
# | DEFAULT_e1931_00012 | TERMINATED |                    |            2 |   64 |   16 | 0.0332736   | 2.34474 |     0.1004 |                    1 |
# | DEFAULT_e1931_00013 | TERMINATED |                    |           16 |  128 |   16 | 0.00126647  | 1.74256 |     0.3499 |                    1 |
# | DEFAULT_e1931_00014 | TERMINATED |                    |            4 |  256 |   64 | 0.0364919   | 2.31824 |     0.0988 |                    1 |
# | DEFAULT_e1931_00015 | TERMINATED |                    |            8 |   64 |   32 | 0.0134564   | 1.75736 |     0.3551 |                    1 |
# | DEFAULT_e1931_00016 | TERMINATED |                    |            4 |  256 |    4 | 0.000144803 | 2.30459 |     0.1001 |                    1 |
# | DEFAULT_e1931_00017 | TERMINATED |                    |            2 |   64 |   64 | 0.00759149  | 2.19196 |     0.1886 |                    1 |
# | DEFAULT_e1931_00018 | TERMINATED |                    |            4 |  128 |  128 | 0.00141191  | 1.251   |     0.5764 |                    8 |
# +---------------------+------------+--------------------+--------------+------+------+-------------+---------+------------+----------------------+
# ... 80 more trials not shown (80 TERMINATED)
#
#
# == Status ==
# Memory usage on this node: 8.6/94.3 GiB
# Using AsyncHyperBand: num_stopped=93
# Bracket: Iter 16.000: None | Iter 8.000: -1.1740097118311978 | Iter 4.000: -1.2300583099722862 | Iter 2.000: -1.4600140343755483 | Iter 1.000: -1.8708154000163078
# Resources requested: 0/40 CPUs, 0.0/4 GPUs, 0.0/53.52 GiB heap, 0.0/18.46 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /home/brian/ray_results/DEFAULT
# Number of trials: 100 (100 TERMINATED)
# +---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc   |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_e1931_00000 | TERMINATED |       |           16 |    4 |   32 | 0.00481312  | 1.46849 |     0.4725 |                   10 |
# | DEFAULT_e1931_00001 | TERMINATED |       |           16 |   64 |  256 | 0.00120355  | 1.73895 |     0.3546 |                    1 |
# | DEFAULT_e1931_00002 | TERMINATED |       |            2 |    4 |   32 | 0.000811232 | 1.37863 |     0.4972 |                    4 |
# | DEFAULT_e1931_00003 | TERMINATED |       |           16 |  128 |    4 | 0.000676203 | 2.24586 |     0.1496 |                    1 |
# | DEFAULT_e1931_00004 | TERMINATED |       |            8 |  256 |   64 | 0.00126235  | 1.14183 |     0.6215 |                   10 |
# | DEFAULT_e1931_00005 | TERMINATED |       |            8 |   16 |    4 | 0.018445    | 2.22298 |     0.1311 |                    1 |
# | DEFAULT_e1931_00006 | TERMINATED |       |            8 |    4 |    8 | 0.022584    | 2.3091  |     0.1023 |                    1 |
# | DEFAULT_e1931_00007 | TERMINATED |       |            8 |    8 |   64 | 0.0142178   | 1.94228 |     0.2667 |                    1 |
# | DEFAULT_e1931_00008 | TERMINATED |       |            8 |  256 |  256 | 0.0399655   | 2.1849  |     0.1636 |                    1 |
# | DEFAULT_e1931_00009 | TERMINATED |       |            8 |   16 |    8 | 0.000980411 | 1.63082 |     0.3787 |                    2 |
# | DEFAULT_e1931_00010 | TERMINATED |       |           16 |    8 |   64 | 0.000851984 | 1.84785 |     0.2928 |                    1 |
# | DEFAULT_e1931_00011 | TERMINATED |       |            2 |   16 |   64 | 0.000231341 | 1.2586  |     0.5498 |                    4 |
# | DEFAULT_e1931_00012 | TERMINATED |       |            2 |   64 |   16 | 0.0332736   | 2.34474 |     0.1004 |                    1 |
# | DEFAULT_e1931_00013 | TERMINATED |       |           16 |  128 |   16 | 0.00126647  | 1.74256 |     0.3499 |                    1 |
# | DEFAULT_e1931_00014 | TERMINATED |       |            4 |  256 |   64 | 0.0364919   | 2.31824 |     0.0988 |                    1 |
# | DEFAULT_e1931_00015 | TERMINATED |       |            8 |   64 |   32 | 0.0134564   | 1.75736 |     0.3551 |                    1 |
# | DEFAULT_e1931_00016 | TERMINATED |       |            4 |  256 |    4 | 0.000144803 | 2.30459 |     0.1001 |                    1 |
# | DEFAULT_e1931_00017 | TERMINATED |       |            2 |   64 |   64 | 0.00759149  | 2.19196 |     0.1886 |                    1 |
# | DEFAULT_e1931_00018 | TERMINATED |       |            4 |  128 |  128 | 0.00141191  | 1.251   |     0.5764 |                    8 |
# | DEFAULT_e1931_00019 | TERMINATED |       |            4 |  256 |  256 | 0.0662201   | 2.34188 |     0.0967 |                    1 |
# | DEFAULT_e1931_00020 | TERMINATED |       |            2 |    4 |  256 | 0.0286478   | 2.32566 |     0.0981 |                    1 |
# | DEFAULT_e1931_00021 | TERMINATED |       |           16 |  128 |  128 | 0.0110741   | 1.41323 |     0.5173 |                    4 |
# | DEFAULT_e1931_00022 | TERMINATED |       |            2 |  256 |   32 | 0.000735972 | 1.19651 |     0.6066 |                    8 |
# | DEFAULT_e1931_00023 | TERMINATED |       |           16 |  256 |  128 | 0.00023935  | 2.29227 |     0.1738 |                    1 |
# | DEFAULT_e1931_00024 | TERMINATED |       |            8 |  256 |   64 | 0.0352421   | 2.10595 |     0.2021 |                    1 |
# | DEFAULT_e1931_00025 | TERMINATED |       |            8 |   16 |   64 | 0.00427362  | 1.46796 |     0.4684 |                    2 |
# | DEFAULT_e1931_00026 | TERMINATED |       |           16 |    8 |   16 | 0.00409285  | 1.46141 |     0.4864 |                    2 |
# | DEFAULT_e1931_00027 | TERMINATED |       |            4 |  256 |    4 | 0.00763769  | 1.87615 |     0.2763 |                    1 |
# | DEFAULT_e1931_00028 | TERMINATED |       |            8 |    4 |   64 | 0.00285792  | 1.57435 |     0.423  |                    2 |
# | DEFAULT_e1931_00029 | TERMINATED |       |            8 |    8 |  256 | 0.0161909   | 2.02949 |     0.237  |                    1 |
# | DEFAULT_e1931_00030 | TERMINATED |       |            8 |    4 |  256 | 0.00016834  | 2.28519 |     0.1369 |                    1 |
# | DEFAULT_e1931_00031 | TERMINATED |       |            2 |   32 |  128 | 0.000164034 | 1.0928  |     0.6162 |                   10 |
# | DEFAULT_e1931_00032 | TERMINATED |       |            4 |  128 |   16 | 0.0615515   | 2.32571 |     0.1006 |                    1 |
# | DEFAULT_e1931_00033 | TERMINATED |       |            4 |    4 |    4 | 0.0415738   | 2.30607 |     0.1032 |                    1 |
# | DEFAULT_e1931_00034 | TERMINATED |       |            8 |    8 |  128 | 0.0121234   | 1.83489 |     0.315  |                    2 |
# | DEFAULT_e1931_00035 | TERMINATED |       |            8 |  256 |   16 | 0.0028954   | 1.25475 |     0.5952 |                    8 |
# | DEFAULT_e1931_00036 | TERMINATED |       |            8 |   16 |    4 | 0.00441369  | 1.52606 |     0.4334 |                    2 |
# | DEFAULT_e1931_00037 | TERMINATED |       |           16 |    4 |    4 | 0.0189872   | 2.30839 |     0.0975 |                    1 |
# | DEFAULT_e1931_00038 | TERMINATED |       |            2 |   32 |   32 | 0.00307402  | 1.71525 |     0.3768 |                    2 |
# | DEFAULT_e1931_00039 | TERMINATED |       |            2 |    8 |  128 | 0.0012714   | 1.50994 |     0.4604 |                    2 |
# | DEFAULT_e1931_00040 | TERMINATED |       |           16 |  256 |   16 | 0.0472842   | 2.22426 |     0.1442 |                    1 |
# | DEFAULT_e1931_00041 | TERMINATED |       |            8 |   32 |   32 | 0.00020919  | 2.29637 |     0.1514 |                    1 |
# | DEFAULT_e1931_00042 | TERMINATED |       |            2 |    8 |    4 | 0.0140202   | 2.31756 |     0.1024 |                    1 |
# | DEFAULT_e1931_00043 | TERMINATED |       |            4 |   64 |    8 | 0.000454658 | 1.48638 |     0.4607 |                    2 |
# | DEFAULT_e1931_00044 | TERMINATED |       |            2 |   16 |   64 | 0.085364    | 2.35809 |     0.0993 |                    1 |
# | DEFAULT_e1931_00045 | TERMINATED |       |           16 |    8 |   16 | 0.000557642 | 2.18937 |     0.1952 |                    1 |
# | DEFAULT_e1931_00046 | TERMINATED |       |            2 |   16 |    8 | 0.00877865  | 2.31909 |     0.0986 |                    1 |
# | DEFAULT_e1931_00047 | TERMINATED |       |            2 |   32 |    4 | 0.00281691  | 1.86748 |     0.2988 |                    2 |
# | DEFAULT_e1931_00048 | TERMINATED |       |            8 |   64 |  128 | 0.00297199  | 1.17814 |     0.5937 |                   10 |
# | DEFAULT_e1931_00049 | TERMINATED |       |            4 |  128 |   32 | 0.00016189  | 2.09    |     0.2448 |                    1 |
# | DEFAULT_e1931_00050 | TERMINATED |       |           16 |    4 |   64 | 0.000305767 | 2.28588 |     0.146  |                    1 |
# | DEFAULT_e1931_00051 | TERMINATED |       |            8 |   16 |   64 | 0.00880819  | 1.67569 |     0.4028 |                    2 |
# | DEFAULT_e1931_00052 | TERMINATED |       |            2 |   16 |    4 | 0.000118683 | 2.13332 |     0.1912 |                    1 |
# | DEFAULT_e1931_00053 | TERMINATED |       |           16 |    8 |   16 | 0.0112715   | 1.62417 |     0.4286 |                    2 |
# | DEFAULT_e1931_00054 | TERMINATED |       |            8 |    4 |   16 | 0.0153406   | 2.06186 |     0.1925 |                    1 |
# | DEFAULT_e1931_00055 | TERMINATED |       |            2 |  128 |   64 | 0.000149303 | 1.25205 |     0.5551 |                    4 |
# | DEFAULT_e1931_00056 | TERMINATED |       |            4 |    8 |   16 | 0.000383268 | 1.56184 |     0.4262 |                    2 |
# | DEFAULT_e1931_00057 | TERMINATED |       |            2 |  128 |   64 | 0.00492752  | 1.96237 |     0.2747 |                    1 |
# | DEFAULT_e1931_00058 | TERMINATED |       |           16 |  256 |   16 | 0.0258697   | 1.78388 |     0.3132 |                    2 |
# | DEFAULT_e1931_00059 | TERMINATED |       |            2 |    4 |    8 | 0.00316008  | 2.01216 |     0.1902 |                    1 |
# | DEFAULT_e1931_00060 | TERMINATED |       |           16 |   64 |  256 | 0.00713198  | 1.29198 |     0.5409 |                    4 |
# | DEFAULT_e1931_00061 | TERMINATED |       |            4 |   64 |   64 | 0.000174592 | 2.02753 |     0.256  |                    1 |
# | DEFAULT_e1931_00062 | TERMINATED |       |            4 |   16 |    8 | 0.0720233   | 2.33276 |     0.0961 |                    1 |
# | DEFAULT_e1931_00063 | TERMINATED |       |            4 |  128 |  256 | 0.000301224 | 1.4902  |     0.4622 |                    2 |
# | DEFAULT_e1931_00064 | TERMINATED |       |           16 |  128 |   16 | 0.00836229  | 1.27813 |     0.5622 |                    4 |
# | DEFAULT_e1931_00065 | TERMINATED |       |            2 |   64 |   32 | 0.000441456 | 1.28817 |     0.5428 |                    4 |
# | DEFAULT_e1931_00066 | TERMINATED |       |           16 |  128 |  256 | 0.0311754   | 1.80072 |     0.3504 |                    2 |
# | DEFAULT_e1931_00067 | TERMINATED |       |            2 |    8 |   64 | 0.0265169   | 2.33722 |     0.1039 |                    1 |
# | DEFAULT_e1931_00068 | TERMINATED |       |            2 |    8 |  128 | 0.000194048 | 1.48026 |     0.4564 |                    2 |
# | DEFAULT_e1931_00069 | TERMINATED |       |            4 |  256 |   32 | 0.0302672   | 2.32277 |     0.105  |                    1 |
# | DEFAULT_e1931_00070 | TERMINATED |       |            4 |    8 |   64 | 0.0174154   | 2.31702 |     0.1348 |                    1 |
# | DEFAULT_e1931_00071 | TERMINATED |       |            2 |  256 |   64 | 0.000656798 | 1.18342 |     0.6104 |                    8 |
# | DEFAULT_e1931_00072 | TERMINATED |       |            8 |    4 |   64 | 0.0892695   | 2.31636 |     0.1023 |                    1 |
# | DEFAULT_e1931_00073 | TERMINATED |       |            8 |   32 |  256 | 0.00133336  | 1.1646  |     0.5883 |                    8 |
# | DEFAULT_e1931_00074 | TERMINATED |       |            8 |  128 |   32 | 0.000298375 | 2.0771  |     0.247  |                    1 |
# | DEFAULT_e1931_00075 | TERMINATED |       |           16 |    8 |  256 | 0.00427008  | 1.32188 |     0.5264 |                    4 |
# | DEFAULT_e1931_00076 | TERMINATED |       |            8 |    4 |   32 | 0.0063324   | 1.59303 |     0.4054 |                    2 |
# | DEFAULT_e1931_00077 | TERMINATED |       |            8 |  128 |    4 | 0.0254909   | 2.31062 |     0.1018 |                    1 |
# | DEFAULT_e1931_00078 | TERMINATED |       |            8 |   64 |    8 | 0.00427982  | 1.38736 |     0.5105 |                    4 |
# | DEFAULT_e1931_00079 | TERMINATED |       |            8 |   32 |   16 | 0.000128594 | 2.29756 |     0.1004 |                    1 |
# | DEFAULT_e1931_00080 | TERMINATED |       |           16 |  128 |  128 | 0.0034125   | 1.17037 |     0.6163 |                   10 |
# | DEFAULT_e1931_00081 | TERMINATED |       |           16 |    8 |    8 | 0.00347646  | 1.50852 |     0.4389 |                    2 |
# | DEFAULT_e1931_00082 | TERMINATED |       |           16 |  256 |  256 | 0.00340609  | 1.25658 |     0.6011 |                   10 |
# | DEFAULT_e1931_00083 | TERMINATED |       |            2 |   16 |    8 | 0.00216756  | 1.62809 |     0.4107 |                    2 |
# | DEFAULT_e1931_00084 | TERMINATED |       |           16 |    8 |   16 | 0.0202151   | 2.00548 |     0.2764 |                    1 |
# | DEFAULT_e1931_00085 | TERMINATED |       |            8 |  128 |  128 | 0.00260189  | 1.2154  |     0.6011 |                    8 |
# | DEFAULT_e1931_00086 | TERMINATED |       |            2 |  256 |   16 | 0.0228712   | 2.33026 |     0.0983 |                    1 |
# | DEFAULT_e1931_00087 | TERMINATED |       |            8 |   16 |   64 | 0.00035588  | 1.93975 |     0.2864 |                    1 |
# | DEFAULT_e1931_00088 | TERMINATED |       |            8 |   16 |  256 | 0.000172065 | 2.13166 |     0.2231 |                    1 |
# | DEFAULT_e1931_00089 | TERMINATED |       |            2 |   16 |   64 | 0.00102759  | 1.32197 |     0.531  |                    4 |
# | DEFAULT_e1931_00090 | TERMINATED |       |            8 |   16 |   32 | 0.0016719   | 1.24572 |     0.5591 |                    4 |
# | DEFAULT_e1931_00091 | TERMINATED |       |            8 |  256 |   64 | 0.0025626   | 1.29428 |     0.6047 |                   10 |
# | DEFAULT_e1931_00092 | TERMINATED |       |            4 |   64 |    4 | 0.00010762  | 2.30531 |     0.1012 |                    1 |
# | DEFAULT_e1931_00093 | TERMINATED |       |            8 |    8 |  256 | 0.00864216  | 1.75123 |     0.3512 |                    2 |
# | DEFAULT_e1931_00094 | TERMINATED |       |           16 |  128 |  256 | 0.000264965 | 2.18392 |     0.2229 |                    1 |
# | DEFAULT_e1931_00095 | TERMINATED |       |           16 |    4 |   16 | 0.0181777   | 1.91291 |     0.2679 |                    1 |
# | DEFAULT_e1931_00096 | TERMINATED |       |            8 |   32 |  256 | 0.076818    | 2.30814 |     0.1029 |                    1 |
# | DEFAULT_e1931_00097 | TERMINATED |       |            2 |   16 |   32 | 0.0172503   | 2.33111 |     0.0994 |                    1 |
# | DEFAULT_e1931_00098 | TERMINATED |       |            2 |  128 |    8 | 0.000160406 | 1.93861 |     0.2594 |                    1 |
# | DEFAULT_e1931_00099 | TERMINATED |       |            8 |  256 |   32 | 0.0035387   | 1.23368 |     0.5918 |                    8 |
# +---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------+
# Best trial config: {'num_gpus': 0.25, 'num_cpus_for_driver': 1, 'num_cpus_per_worker': 1, 'num_workers': 2, 'l1': 32, 'l2': 128, 'lr': 0.00016403435434371365, 'batch_size': 2}
# Best trial final validation loss: 1.0928039968871512
# Best trial final validation accuracy: 0.6162
# Files already downloaded and verified
# Files already downloaded and verified
# Best trial test set accuracy: 0.6147
